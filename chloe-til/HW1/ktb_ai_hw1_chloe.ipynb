# %% [markdown]
# #### Chill Guy와 일일 데이트
#
# ![image.png](data:image/png;base64,...)

# %%
import time

def print_slow(text, delay=0.03):
    for char in text:
        print(char, end='', flush=True)
        time.sleep(delay)
    print()

def chill_guy_ascii():
    print("""
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠛⣿⣿⣿⣿⡿⠟⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠏⠀⠀⢸⣿⣿⠋⠀⣀⠀⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⣿⣿⠇⢀⣷⠃⢰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠀⣀⣿⣿⠀⣼⠇⢠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠿⠟⠉⠉⠀⠉⠉⠛⠁⠟⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠟⠛⠋⣉⣭⣤⣄⡀⠀⢰⣶⣶⣶⣶⣦⣄⡀⠀⠀⠚⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿⠿⠟⠛⠋⠉⠁⠀⠀⠀⠀⠀⠈⢋⣿⣯⣭⣟⠀⣈⣽⣯⣭⣭⣋⠛⠀⠀⠀⠀⠈⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢟⣛⣭⣷⣷⣿⣿⣆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣏⢹⣿⣿⢀⠈⢛⠉⣿⣿⢿⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢟⣵⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠐⠋⠁⠁⠀⠈⠁⠙⠉⠈⠀⠀⠀⠀⠀⠀⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢏⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡧⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡐⠠⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠐⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠐⠠⢁⠐⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⢻⣿⣿⣿⣿⣿⣿⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣷⣦⡌⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⣝⡻⠿⡛⠋⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⢀⣀⣀⣤⣶⠾⠟⠋⠈⠁⠀⠀⠀⠁⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣶⣤⣀⡤⣤⣄⣀⣠⡀⠀⠀⠂⠀⠀⠀⠚⠛⠫⠍⠁⢂⡌⠀⠀⠀⠀⠀⠀⠀⠀⠀⢼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀⡀⠀⠀⠀⠀⠀⠈⠳⠶⠟⠛⠁⠀⠀⠀⠀⠀⠀⣀⣤⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⣷⡦⣤⣤⣀⣀⣀⣀⣀⣀⣀⣀⣀⣤⣤⣤⡴⢾⣻⣯⠿⠋⠉⠉⠻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⢡⠀⠉⠛⠺⠯⣽⣍⣽⣉⣹⣹⣍⣉⣧⣼⠶⠿⠚⠉⠁⠀⢀⠀⠀⠀⠘⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠁⡆⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣦⡾⠁⠀⠀⠀⠘⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣏⠁⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠁⣠⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⡄⠀⠀⢀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠈⠛⣇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢈⡷⠄⣟⡋⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣻⣿⣿⣿⡇⠀⢻⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⡟⠁⠀⠉⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣄⢨⣿⣦⣤⣤⣀⣀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣀⣼⡅⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠈⠙⠻⠿⣭⣯⣻⣟⢿⠻⣟⢿⣻⣻⣿⡿⠽⠛⠹⣿⢦⡀⠀⠀⢠⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡄⠀⠀⠻⡷⣛⡛⣯⣭⣿⠩⢉⢉⡁⡀⠀⠀⠀⠀⠈⠛⠿⠟⢺⢩⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⠀⠀⠉⠒⠯⠽⣿⣾⣶⣦⣤⠤⠆⠀⠀⠀⠈⠲⢌⡐⠂⢸⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⡿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⢰⢣⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣇⠀⠘⠮⡢⢤⡀⠀⠈⡞⡆⠀⠀⢤⣄⠀⠀⠀⠀⠀⠀⠀⣿⢨⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⠈⠀⠀⠀⠀⢹⢹⠀⠀⠈⠢⡑⠦⠀⠀⠀⠀⠀⣿⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣟⠳⠤⣄⣀⣀⣀⣀⣀⣀⣿⣦⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⣿⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡄⠀⠀⠀⠉⠉⠉⠉⠁⠀⢷⠈⠉⠛⠛⠻⠿⠾⠗⠛⠛⠋⡏⢹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣀⠀⢀⡀⠀⠀⠀⠀⠀⢸⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢱⢼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠛⠛⠿⣿⣟⢻⡿⢷⣷⣤⣦⣦⣧⣐⣤⣤⣤⣄⣤⣠⣦⣤⣶⣾⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠀⠀⠀⠀⠈⠻⣆⣿⡟⡛⣍⢣⣐⣾⣿⣿⣿⣛⣿⣿⡿⡿⢿⡦⣘⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠐⠈⠀⠀⠀⠘⡿⢣⣱⣌⡿⠛⠁⠀⠀⠀⠉⠻⣿⣿⣹⢆⢳⣔⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⣤⣤⣤⣤⣤⣤⣤⠽⣆⣿⣾⡇⠀⠀⠀⠄⠚⠀⠀⠈⢻⣉⣾⢿⣽⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣾⣿⣿⣿⣿⣿⣿⣷⡑⠂⠤⠤⠤⠤⠤⠐⠚⠉⣡⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣶⣶⣶⢶⡶⣶⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
    """)

def start_date():
    chill_guy_ascii()
    print_slow("\n어, 안녕. 난 Chill Guy야. 오늘 하루 데이트라... 뭐, 그럴 수도 있지. 인생이 그렇듯이.")
    print_slow("아침부터 시작해볼까? 뭐 하고 싶어?")
    print_slow("1. 공원에서 피크닉")
    print_slow("2. 카페에서 브런치")
    print_slow("3. 자전거 타기")

    choice = input("\n> ").strip()

    if choice == "1":
        morning_picnic()
    elif choice == "2":
        morning_brunch()
    elif choice == "3":
        morning_bike()
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 가만히 있어도 돼. 시간은 알아서 흘러가니까.")
        start_date()

def morning_picnic():
    chill_guy_ascii()
    print_slow("\n공원에 왔어. 피크닉 매트도 깔았고. 이제 뭐하지?")
    print_slow("1. 샌드위치 먹기")
    print_slow("2. 책 읽기")
    print_slow("3. 잠깐 낮잠 자기")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 샌드위치? 좋아. 인생은 샌드위치와 같아. 때론 달콤하고, 때론 짜고... 근데 결국 다 먹게 되지. 냠냠.")
    elif choice == "2":
        print_slow("\nChill Guy: 책? 좋아. 책 읽다 보면 시간이 어떻게 가는지 모르지. 근데 그게 중요해? 시간은 원래 그렇게 흘러가는 거야.")
    elif choice == "3":
        print_slow("\nChill Guy: 낮잠? 좋아. 잠들면 모든 게 chill해져. 꿈에서 만나자. 아니면 말고.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 가만히 있어도 돼. 바람 소리 들으면서.")
        morning_picnic()

    lunch_choice()

def morning_brunch():
    chill_guy_ascii()
    print_slow("\n카페에 왔어. 브런치 메뉴가 많네. 뭐 먹을래?")
    print_slow("1. 에그 베네딕트")
    print_slow("2. 아보카도 토스트")
    print_slow("3. 팬케이크")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 에그 베네딕트... 달걀이 흘러내리는 게 인생 같아. 예측할 수 없지만 맛있잖아.")
    elif choice == "2":
        print_slow("\nChill Guy: 아보카도 토스트? 건강한 선택이네. 근데 인생에서 가장 건강한 선택이 뭘까? 아마 여유를 갖는 거겠지.")
    elif choice == "3":
        print_slow("\nChill Guy: 팬케이크라... 달콤한 게 좋아? 인생도 가끔은 달콤해야 해. 근데 너무 달면 질리니까 적당히.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 물만 마셔도 돼. 단식도 나름대로 의미가 있다더라고.")
        morning_brunch()

    lunch_choice()

def morning_bike():
    chill_guy_ascii()
    print_slow("\n자전거 타러 왔어. 어디로 갈까?")
    print_slow("1. 강변 따라 가기")
    print_slow("2. 산길로 가기")
    print_slow("3. 그냥 아무 데로나 가기")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 강변이라... 물 흐르는 걸 보면 인생의 이치를 깨달을 수 있대. 뭐, 아무것도 깨닫지 못해도 상관없지만.")
    elif choice == "2":
        print_slow("\nChill Guy: 산길이라... 힘들겠지만 정상에 오르면 뭔가 있겠지. 허무할 수도 있고. 그게 인생이야.")
    elif choice == "3":
        print_slow("\nChill Guy: 아무 데로나 가는 거라... 좋아. 인생도 그런 거 아닐까? 목적지 모르고 가다 보면 어느새 도착해 있는 거지.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 여기 서 있어도 돼. 서 있는 것도 나름의 여행이니까.")
        morning_bike()

    lunch_choice()

def lunch_choice():
    chill_guy_ascii()
    print_slow("\n어느새 점심시간이네. 배고프지 않아? 뭐 먹을래?")
    print_slow("1. 길거리 음식")
    print_slow("2. 레스토랑")
    print_slow("3. 도시락")

    choice = input("\n> ").strip()

    if choice == "1":
        lunch_street_food()
    elif choice == "2":
        lunch_restaurant()
    elif choice == "3":
        lunch_packed()
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 굶어도 돼. 단식이 몸에 좋다더라고.")
        lunch_choice()

def lunch_street_food():
    chill_guy_ascii()
    print_slow("\n길거리 음식이라... 좋아. 인생의 맛은 길거리에 있는 법이지.")
    print_slow("1. 떡볶이")
    print_slow("2. 타코")
    print_slow("3. 핫도그")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 떡볶이라... 매운 맛이 인생의 고난 같아. 근데 그 매운 맛이 끝나면 또 먹고 싶어지는 게 인생이지.")
    elif choice == "2":
        print_slow("\nChill Guy: 타코... 여러 가지 재료가 한데 어우러지는 게 인생 같아. 때론 흐트러질 수 있어도 맛있잖아.")
    elif choice == "3":
        print_slow("\nChill Guy: 핫도그... 길고 가느다란 게 인생의 여정 같아. 근데 중간중간 맛있는 순간들이 있지.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 구경만 해도 돼. 보는 것만으로도 배부를 수 있다더라고.")
        lunch_street_food()

    afternoon_choice()

def lunch_restaurant():
    chill_guy_ascii()
    print_slow("\n레스토랑에 왔어. 뭐, 분위기는 좋네. 근데 메뉴가 너무 많아서 고르기 힘들어.")
    print_slow("1. 스테이크")
    print_slow("2. 파스타")
    print_slow("3. 샐러드")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 스테이크라... 좋아. 인생도 가끔은 호사를 부려야 해. 근데 먹고 나면 또 평범해지는 게 묘미지.")
    elif choice == "2":
        print_slow("\nChill Guy: 파스타... 복잡하게 얽혀있다고? 그래, 근데 결국 다 같은 면이야. 인생도 그렇지 않을까?")
    elif choice == "3":
        print_slow("\nChill Guy: 샐러드... 건강을 위해서라고? 맞아. 건강해야 여유롭게 살 수 있지. 근데 가끔은 치팅데이도 필요해.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 물만 마셔도 돼. 단식도 나름대로 의미가 있다더라고.")
        lunch_restaurant()

    afternoon_choice()

def lunch_packed():
    chill_guy_ascii()
    print_slow("\n도시락을 싸왔네. 직접 만든 거야? 뭐가 들었을지 궁금하네.")
    print_slow("1. 김밥")
    print_slow("2. 샌드위치")
    print_slow("3. 볶음밥")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 김밥이라... 여러 가지가 조화롭게 어우러진 게 인생 같아. 각자의 맛이 있으면서도 함께 있을 때 더 맛있지.")
    elif choice == "2":
        print_slow("\nChill Guy: 샌드위치... 층층이 쌓인 게 인생의 경험 같아. 때로는 무너질 수도 있지만, 그래도 맛있잖아.")
    elif choice == "3":
        print_slow("\nChill Guy: 볶음밥... 이것저것 섞여 있는 게 인생의 복잡함 같아. 근데 그 복잡함이 오히려 맛을 내는 거지.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 도시락 구경만 해도 돼. 보는 것만으로도 배부를 수 있다더라고.")
        lunch_packed()

    afternoon_choice()

def afternoon_choice():
    chill_guy_ascii()
    print_slow("\n점심 먹고 나니 좀 나른하네. 오후에는 뭐 할까?")
    print_slow("1. 영화 보기")
    print_slow("2. 미술관 가기")
    print_slow("3. 공원에서 산책하기")

    choice = input("\n> ").strip()

    if choice == "1":
        afternoon_movie()
    elif choice == "2":
        afternoon_art_gallery()
    elif choice == "3":
        afternoon_park_walk()
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 아무것도 안 해도 돼. 가만히 있는 것도 때론 필요하지.")
        afternoon_choice()

def afternoon_movie():
    chill_guy_ascii()
    print_slow("\n영화관에 왔어. 뭐 볼래?")
    print_slow("1. 액션 영화")
    print_slow("2. 로맨틱 코미디")
    print_slow("3. 다큐멘터리")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 액션 영화라... 긴장감 넘치는 거 좋아하네. 인생도 때론 그렇지. 근데 영화가 끝나면 다시 일상으로 돌아오는 거야.")
    elif choice == "2":
        print_slow("\nChill Guy: 로맨틱 코미디... 달달한 거 좋아해? 인생도 가끔은 그래야 해. 근데 너무 달면 질리니까 적당히.")
    elif choice == "3":
        print_slow("\nChill Guy: 다큐멘터리... 현실을 보고 싶은가 봐. 좋아. 근데 기억해, 우리의 현실도 누군가에겐 다큐멘터리일 수 있어.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 팝콘만 먹어도 돼. 영화는 안 봐도 팝콘은 맛있으니까.")
        afternoon_movie()

    evening_choice()

def afternoon_art_gallery():
    chill_guy_ascii()
    print_slow("\n미술관에 왔어. 어떤 전시를 볼까?")
    print_slow("1. 현대 미술")
    print_slow("2. 고전 명화")
    print_slow("3. 사진 전시")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 현대 미술이라... 이해가 안 돼도 괜찮아. 인생도 마찬가지잖아. 이해할 수 없는 게 많지.")
    elif choice == "2":
        print_slow("\nChill Guy: 고전 명화... 옛날 사람들도 우리처럼 고민하고 살았나 봐. 시대는 변해도 인간의 본질은 그대로인가.")
    elif choice == "3":
        print_slow("\nChill Guy: 사진 전시... 순간을 담아내는 게 멋지지. 우리 인생도 그런 순간들의 연속이야. 근데 그 순간을 즐기고 있어?")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 벽 구경해도 돼. 빈 벽도 때론 예술이 될 수 있으니까.")
        afternoon_art_gallery()

    evening_choice()

def afternoon_park_walk():
    chill_guy_ascii()
    print_slow("\n공원에 왔어. 산책하면서 뭐 할까?")
    print_slow("1. 나무 구경하기")
    print_slow("2. 벤치에 앉아 사람 구경하기")
    print_slow("3. 호수 주변 걷기")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 나무 구경이라... 나무처럼 묵묵히 자리를 지키는 것도 멋진 일이야. 근데 가끔은 바람에 흔들리는 것도 필요하지.")
    elif choice == "2":
        print_slow("\nChill Guy: 사람 구경... 재밌지. 모두가 각자의 이야기를 가지고 있어. 우리도 누군가에겐 구경거리일 수 있겠네.")
    elif choice == "3":
        print_slow("\nChill Guy: 호수 주변이라... 물처럼 유연하게 살아가는 것도 좋아. 근데 너무 흘러가기만 하면 어디로 가는지 모를 수도 있어.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 가만히 있어도 돼. 때론 아무것도 안 하는 게 최고의 휴식이지.")
        afternoon_park_walk()

    evening_choice()

def evening_choice():
    chill_guy_ascii()
    print_slow("\n어느새 저녁이 됐네. 마지막으로 뭐 할까?")
    print_slow("1. 야경 보러 가기")
    print_slow("2. 조용한 바에서 한잔하기")
    print_slow("3. 집에서 넷플릭스 보기")

    choice = input("\n> ").strip()

    if choice == "1":
        evening_night_view()
    elif choice == "2":
        evening_bar()
    elif choice == "3":
        evening_netflix()
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 잠자리에 들어도 돼. 하루의 끝도 중요하니까.")
        evening_choice()

def evening_night_view():
    chill_guy_ascii()
    print_slow("\n야경을 보러 왔어. 도시의 불빛이 참 예쁘네.")
    print_slow("1. 높은 곳에서 내려다보기")
    print_slow("2. 강변에서 보기")
    print_slow("3. 조용한 뒷골목 거닐기")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 높은 곳에서 보니 도시가 작아 보이네. 우리의 고민도 저 멀리서 보면 작아 보이겠지?")
    elif choice == "2":
        print_slow("\nChill Guy: 강물에 비친 불빛이 참 예뻐. 인생도 이렇게 반짝이는 순간들이 있어야 해.")
    elif choice == "3":
        print_slow("\nChill Guy: 조용한 뒷골목... 화려한 것만이 다가 아니지. 소소한 일상의 아름다움을 발견하는 것도 중요해.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 눈 감고 있어도 돼. 때론 보이지 않는 게 더 아름다울 수 있으니까.")
        evening_night_view()

    end_date()

def evening_bar():
    chill_guy_ascii()
    print_slow("\n조용한 바에 왔어. 뭐 마실래?")
    print_slow("1. 맥주")
    print_slow("2. 와인")
    print_slow("3. 논알코올 칵테일")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 맥주라... 시원하고 좋지. 인생도 이렇게 시원하게 흘러갔으면 좋겠어.")
    elif choice == "2":
        print_slow("\nChill Guy: 와인이라... 오래될수록 맛있어진다지. 우리도 나이 들수록 더 멋져질 거야. 아마도.")
    elif choice == "3":
        print_slow("\nChill Guy: 논알코올 칵테일... 술 없이도 충분히 즐길 수 있다는 거 알아? 인생도 마찬가지야.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 물만 마셔도 돼. 가장 순수한 선택일 수 있어.")
        evening_bar()

    end_date()

def evening_netflix():
    chill_guy_ascii()
    print_slow("\n집에 왔어. 넷플릭스 볼 준비 됐어?")
    print_slow("1. 로맨스 드라마")
    print_slow("2. 스릴러 영화")
    print_slow("3. 다큐멘터리 시리즈")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 로맨스 드라마... 달달한 거 좋아하네. 인생에도 이런 로맨스가 필요하지. 근데 드라마처럼 되진 않겠지?")
    elif choice == "2":
        print_slow("\nChill Guy: 스릴러 영화... 긴장감 있는 거 좋아해? 인생도 때론 스릴 넘치지. 근데 영화와 달리 우리가 주인공이야.")
    elif choice == "3":
        print_slow("\nChill Guy: 다큐멘터리... 세상을 알고 싶어하는구나. 좋아. 근데 기억해, 우리의 삶도 누군가에겐 다큐멘터리일 수 있어.")
    else:
        print_slow("\n음... 뭐라고? 다시 말해봐. 아니면 그냥 화면만 켜놓고 있어도 돼. 백색 소음처럼 편안할 수 있어.")
        evening_netflix()

    end_date()

def end_date():
    chill_guy_ascii()
    print_slow("\n어, 벌써 하루가 끝나가네. 시간이란... 참 웃기지? 붙잡으려 해도 안 잡히고, 놓아주려 해도 안 가고.")
    print_slow("그래서 말인데, 오늘 하루 어땠어? 뭐, 별로였어도 괜찮아. 인생은 ups and downs이니까.")
    print_slow("\n1. 정말 좋았어! 재미있었어!")
    print_slow("2. 그냥 그랬어. 평범했달까?")
    print_slow("3. 음... 좀 별로였어.")

    choice = input("\n> ").strip()

    if choice == "1":
        print_slow("\nChill Guy: 오, 재미있었다고? 그렇구나. 나도... 뭐, 나쁘지 않았어.")
        print_slow("재미라는 게 참 주관적이지. 누군가에겐 롤러코스터가 재미있고, 누군가에겐 그냥 앉아있는 게 재미있고.")
        print_slow("결국 우리가 재미를 느끼는 거지. 재미가 우리를 느끼는 게 아니라. 깊다? 뭐 적당히 알아들어.")
    elif choice == "2":
        print_slow("\nChill Guy: 그냥 그랬다고? 음, 그럴 수 있지. 인생의 대부분은 그냥 그런 날들의 연속이야.")
        print_slow("근데 그 '그냥 그런 날들'이 모여서 우리의 인생이 되는 거 알아? 대단해 보이지 않아도, 그게 다 소중한 거지.")
        print_slow("그러니까 오늘도 소중한 하루였어. 뭐, 내일도 별 다를 건 없겠지만.")
    elif choice == "3":
        print_slow("\nChill Guy: 별로였다고? 흠… 그것도 나쁘지 않아. 왜냐면 말이야, 별로인 날이 있어야 좋은 날도 있는 거거든.")
        print_slow("인생은 마치 음악 같아. 고음만 있으면 시끄럽고, 저음만 있으면 지루해. 높낮이가 있어야 멜로디가 되는 거지.")
        print_slow("그러니까 오늘은 네 인생 음악의 저음 파트였다고 생각해. 뭐, 내일은 고음이 될지도 모르고.")
    else:
        print_slow("\nChill Guy: 음… 뭐라고? 다시 말해도 돼. 아니면 그냥 넘어가도 되고. 말이란 게 다 뭐라고.")


    print_slow("\n자, 이제 집에 갈 시간이네. 근데 말야, 다음에 또 만날 생각 있어? 없어도 상관없어. 우주의 순리대로 살면 되는 거지.")
    print_slow("1. 응, 꼭 다시 만나고 싶어!")
    print_slow("2. 글쎄... 생각해볼게.")
    print_slow("3. 아니, 다음엔 됐어.")

    next_meeting = input("\n> ").strip()

    if next_meeting == "1":
      print_slow("\nChill Guy: 오, 그래? 좋아. 다음에 만나면 또 이런저런 얘기 나누자. 뭐, 별 얘기 안 해도 상관없고.")
      print_slow("시간이 흐르면 우리도 변하고 세상도 변하겠지. 근데 변하지 않는 게 있다면 그건 바로 변한다는 사실?")
      print_slow("어, 좀 복잡한가? 뭐, 그냥 잊어버려도 돼. 중요한 건 우리가 다시 만난다는 거지. 아마도.")
    elif next_meeting == "2":
      print_slow("\nChill Guy: 생각해본다... 음, 그것도 좋아. 생각이란 게 참 신기하지. 있다가도 없고, 없다가도 있고.")
      print_slow("근데 말야, 너무 많이 생각하지 마. 때론 생각 없이 사는 것도 나쁘지 않아. 마치 구름이 흘러가듯이.")
      print_slow("그러다 우연히 만나면 반갑게 인사하고, 안 만나도 그럴 수 있지 뭐. 인생은 그런 거니까.")
    elif next_meeting == "3":
      print_slow("\nChill Guy: 아, 그래? 괜찮아. 모든 만남에는 헤어짐이 있는 법이지. 우리의 만남도 여기까지였나 보다.")
      print_slow("근데 말야, 인생은 참 예측불가능해. 오늘의 끝이 내일의 시작이 될 수도 있고, 안녕이 다시 만나요가 될 수도 있어.")
      print_slow("그러니까 너무 신경 쓰지 마. 그냥 살다 보면 뭐... 될 대로 되는 거지. 그게 인생이야.")
    else:
      print_slow("\nChill Guy: 음... 뭐라고? 아, 뭐, 상관없어. 대답하든 안 하든. 말이란 게 다 뭐라고. 그냥 가는 거지 뭐.")

    print_slow("\n자, 그럼 이만 갈게. 조심히 가고. 뭐, 넘어져도 괜찮아. 인생은 원래 굴곡이 있는 거니까. 안녕.")


start_date()
# Out:
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠛⣿⣿⣿⣿⡿⠟⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠏⠀⠀⢸⣿⣿⠋⠀⣀⠀⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⣿⣿⠇⢀⣷⠃⢰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠀⣀⣿⣿⠀⣼⠇⢠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠿⠟⠉⠉⠀⠉⠉⠛⠁⠟⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠟⠛⠋⣉⣭⣤⣄⡀⠀⢰⣶⣶⣶⣶⣦⣄⡀⠀⠀⠚⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣿⣿⣿⣿⠿⠟⠛⠋⠉⠁⠀⠀⠀⠀⠀⠈⢋⣿⣯⣭⣟⠀⣈⣽⣯⣭⣭⣋⠛⠀⠀⠀⠀⠈⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢟⣛⣭⣷⣷⣿⣿⣆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣏⢹⣿⣿⢀⠈⢛⠉⣿⣿⢿⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢟⣵⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠐⠋⠁⠁⠀⠈⠁⠙⠉⠈⠀⠀⠀⠀⠀⠀⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢏⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ...
